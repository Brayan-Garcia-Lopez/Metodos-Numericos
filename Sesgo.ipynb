# %% [markdown]
# <a href="https://colab.research.google.com/github/Brayan-Garcia-Lopez/Metodos-Numericos/blob/main/Sesgo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SESGO
import numpy as np
# Se generan 1000 datos aleatorios
datos_reales = np.random.normal(0,1,1000)
# Se define el valor del sesgo (bias)
sesgo = 0.5
print(datos_reales)
#se agrega sesgo a cada rato
datos_sesgados = datos_reales + sesgo
print(datos_sesgados)
print("Media real", np.mean(datos_reales))
print("Media Sesgada", np.mean(datos_sesgados))
