# %% [markdown]
# <a href="https://colab.research.google.com/github/Brayan-Garcia-Lopez/Metodos-Numericos/blob/main/Regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#aplicacion: regresion lineal

import numpy as np

x = np.array([[1,1], #Matriz de datos donde la primera columna es el termino independiente
              [1,2,], #segunda observacion del conjunto de datos
              [1,3],  #Tercera observacion
              [1,4]])  #Cuarta observacion



y = np.array([6,5,7,10]) #vector de valores observados

XT = x.T #Calcula la transpuesta de la matriz de datos

beta = np.linalg.inv(XT.dot(x)).dot(XT).dot(y) #Calcula los coeficientes de la regresion lineal

print("coeficientes del modelo: ", beta) #imprime los parametros estimados del modelo
# Out:
# coeficientes del modelo:  [3.5 1.4]
