# %% [markdown]
# <a href="https://colab.research.google.com/github/Brayan-Garcia-Lopez/Metodos-Numericos/blob/main/Error_Numerico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ERROR NUMERICO
import numpy as np
# Valor con alta precisión (aproximación de pi)
x = 3.1415926535

# Redondeo a diferente número de decimales
print(round(x,2))
print(round(x,4))
print(round(x,6))

#Menos cifras --> mas error numerico
#Impacto acumulativo en algoritmos iterativos
