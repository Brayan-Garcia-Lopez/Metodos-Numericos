# %% [markdown]
# <a href="https://colab.research.google.com/github/Brayan-Garcia-Lopez/Metodos-Numericos/blob/main/implementacion_biseccion_manual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#implementacion biseccion manual
import numpy as np

def g(x): #definicion d ela funcion iterativa g(x)
  return np.cos(x) #Funcion coseano que define el punto fijo

x = 0.5 #Valor inicial de la aproximacion
tolerancia = 1e-6 # error maximo permitido
max_iter = 100 #Numero maximo de iteraciones

for i in range(max_iter): #ciclo de iteracion
  x_nuevo = g(x) #Aplicacione de la formula de aproximacion sucesiva

  if abs(x_nuevo - x) < tolerancia: #Criterio de para basado en error absoluto
    break #Termina si la diferencia es sufucientemente pequeña

  x = x_nuevo #Actualizacion del valor para la siguinete iteracion

print("La raiz aproximada es: ", x_nuevo) #Mostrar el resultado final
print("Iteraciones realizadas: ", i+1) #Mostrar numero de iteraciones
# Out:
# La raiz aproximada es:  0.7390848229131413
# Iteraciones realizadas:  34

# %%
# interpolacion lineal manual

x0 = 1 #Primer punto en x
y0 = 2 #Valor correspondiente en y
x1 = 3 #Segundo valor en x
y1 = 6 #Valor correspondiente en y

x = 2 #Punto donde se desea interpolar

P = y0 + ((y1-y0)/(x1-x0))*(x-x0) #formula de la interpolacion

print("Valor interpolado: ", P)# Mostrar resultado
# Out:
# Valor interpolado:  4.0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 3, 100)
y = y0 + ((y1-y0)/(x1-x0))*(x-x0)

plt.axhline(0)
plt.plot(x, y)
plt.title("Funcion f(x) = y0 + ((y1-y0)/(x1-x0))*(x-x0)")
plt.show()

# %%
#Interpolacion con Numpy
import numpy as np #Biblioteca numerica

x_datos = np.array([0,1,2]) # arreglo con valores conocidos en x
y_datos = np.array([1,3,2]) # arreglo con valores conocidos en y

coeficientes = np.polyfit(x_datos, y_datos, 2) # ajuste de polinomio grado 2
polinomio = np.poly1d(coeficientes) #Construccion del polinomio

x_eval = 1.5 # Punto donde se evaluara el polinomio
y_eval = polinomio(x_eval) # Evaluacion del polinomio

print("Coeficiente del polinomio", coeficientes) #mostrar coeficientes
print("Valor interpolado: ",y_eval) #Mostrar valor interpolado

#graficar el grafico
# Out:
# Coeficiente del polinomio [-1.5  3.5  1. ]
# Valor interpolado:  2.8750000000000018
